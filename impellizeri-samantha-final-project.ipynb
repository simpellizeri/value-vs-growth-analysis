# %%
# !pip install openassetpricing pandas-datareader fredapi
# Out:
# Requirement already satisfied: openassetpricing in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.0.2)
# Requirement already satisfied: pandas-datareader in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.10.0)
# Requirement already satisfied: fredapi in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.5.2)
# Requirement already satisfied: polars in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openassetpricing) (1.40.0)
# Requirement already satisfied: pandas in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openassetpricing) (2.2.3)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (from openassetpricing) (2.32.5)
# Requirement already satisfied: tabulate in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openassetpricing) (0.10.0)
# Requirement already satisfied: wrds in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openassetpricing) (3.5.0)
# Requirement already satisfied: pyarrow in /usr/local/python/3.12.1/lib/python3.12/site-packages (from openassetpricing) (24.0.0)
# Requirement already satisfied: beautifulsoup4 in /home/codespace/.local/lib/python3.12/site-packages (from openassetpricing) (4.14.2)
# Requirement already satisfied: lxml in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas-datareader) (6.1.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas->openassetpricing) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->openassetpricing) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas->openassetpricing) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->openassetpricing) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->openassetpricing) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests->openassetpricing) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests->openassetpricing) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests->openassetpricing) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests->openassetpricing) (2025.11.12)
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4->openassetpricing) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4->openassetpricing) (4.15.0)
# Requirement already satisfied: polars-runtime-32==1.40.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from polars->openassetpricing) (1.40.0)
# Requirement already satisfied: ipython<=9.8.0 in /home/codespace/.local/lib/python3.12/site-packages (from wrds->openassetpricing) (9.7.0)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from wrds->openassetpricing) (2.9.12)
# Requirement already satisfied: sqlalchemy<2.1,>=2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from wrds->openassetpricing) (2.0.49)
# Requirement already satisfied: decorator>=4.3.2 in /home/codespace/.local/lib/python3.12/site-packages (from ipython<=9.8.0->wrds->openassetpricing) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from ipython<=9.8.0->wrds->openassetpricing) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/codespace/.local/lib/python3.12/site-packages (from ipython<=9.8.0->wrds->openassetpricing) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /home/codespace/.local/lib/python3.12/site-packages (from ipython<=9.8.0->wrds->openassetpricing) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/codespace/.local/lib/python3.12/site-packages (from ipython<=9.8.0->wrds->openassetpricing) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/codespace/.local/lib/python3.12/site-packages (from ipython<=9.8.0->wrds->openassetpricing) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/codespace/.local/lib/python3.12/site-packages (from ipython<=9.8.0->wrds->openassetpricing) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/codespace/.local/lib/python3.12/site-packages (from ipython<=9.8.0->wrds->openassetpricing) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/codespace/.local/lib/python3.12/site-packages (from ipython<=9.8.0->wrds->openassetpricing) (5.14.3)
# Requirement already satisfied: wcwidth in /home/codespace/.local/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<=9.8.0->wrds->openassetpricing) (0.2.14)
# Requirement already satisfied: greenlet>=1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from sqlalchemy<2.1,>=2->wrds->openassetpricing) (3.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/codespace/.local/lib/python3.12/site-packages (from jedi>=0.18.1->ipython<=9.8.0->wrds->openassetpricing) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/codespace/.local/lib/python3.12/site-packages (from pexpect>4.3->ipython<=9.8.0->wrds->openassetpricing) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython<=9.8.0->wrds->openassetpricing) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython<=9.8.0->wrds->openassetpricing) (3.0.1)
# Requirement already satisfied: pure-eval in /home/codespace/.local/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython<=9.8.0->wrds->openassetpricing) (0.2.3)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import openassetpricing as openap
import pandas_datareader.data as web
from fredapi import Fred

# %%
ap = openap.OpenAP()

bm = ap.dl_port('quintiles_ew', 'pandas', ['BM'])
print("BM data shape:", bm.shape)
print("Columns:", bm.columns.tolist())
print(bm.head())
# Out:
# Data is downloaded: 4s
# BM data shape: (5292, 7)
# Columns: ['signalname', 'port', 'date', 'ret', 'signallag', 'Nlong', 'Nshort']
#   signalname port       date       ret  signallag  Nlong  Nshort
# 0         BM   01 1951-07-31  7.976745  -0.854527     65       0
# 1         BM   01 1951-08-31  3.926174  -0.854527     65       0
# 2         BM   01 1951-09-28  1.263965  -0.854527     65       0
# 3         BM   01 1951-10-31 -4.242974  -0.854527     65       0
# 4         BM   01 1951-11-30  1.147037  -0.854527     65       0

# %%
ep  = ap.dl_port('quintiles_ew', 'pandas', ['EP'])
cfp = ap.dl_port('quintiles_ew', 'pandas', ['CFP'])

print("EP shape:", ep.shape)
print("CFP shape:", cfp.shape)
# Out:
# Data is downloaded: 3s
# One or more input predictors are not available.
#
# Data is downloaded: 3s
# EP shape: (5328, 7)
# CFP shape: (0, 7)
